# %%
# This is a Python cell in Jupyter Notebook
print("Hello, VS Code Jupyter Notebook!")
# Out:
# Hello, VS Code Jupyter Notebook!

# %%
from PyPDF2 import PdfReader

# %%
reader = PdfReader("SAM_T_JAMES_Resume_Updated_March.pdf")
number_of_pages = len(reader.pages)
page = reader.pages[0]
text = page.extract_text()

# %%
print(text)
# Out:
# S A M  T J A M E S
# C h e n n a i , I n d i a |  + 9 1  9 9 9 5 9 2 1 8 0 1
# sj6740@srmist.edu.in  | tjmas04 – LinkedI n | tj-mas04 -Github  | tj-mas04 MyPortfolio
#
# PROFESSIONAL SUMMARY
# Results -driven Computer Science undergraduate at SRM Institute of Science and Technology with a strong foundation in
# Machine Learning, Data Engineering, and Full -Stack Development. Skilled in Python, SQL, and cloud platforms, with
# hands -on experience in AI /ML research, data -driven decision -making, and scalable application development. Passionate
# about leveraging technology to solve real -world challenges, optimize processes, and drive impactful innovations. Seeking
# opportunities in AI/ML development, Data En gineering, or Data Analytics to apply my expertise in building intelligent and
# efficient solutions
# E D U C A T I O N
# SRM Institute of Science and Technology , Kattankulathur, Chennai , Indi a  Expected May 202 6
# Bachelor of Technology  (BTech), Computer Science (Core)
# ...
